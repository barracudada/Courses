# %% [markdown]
# ## Базовое использование asyncio.Queue

# %%
import asyncio

async def main():
    queue = asyncio.Queue()
    await queue.put('A')
    await queue.put('B')
    print(await queue.get())
    print(await queue.get())

asyncio.run(main())
