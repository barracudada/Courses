# %% [markdown]
# ## Очередь LIFO (asyncio.LifoQueue)

# %%
import asyncio

async def main():
    queue = asyncio.LifoQueue()
    await queue.put('A')
    await queue.put('B')
    await queue.put('C')
    print(await queue.get())
    print(await queue.get())
    print(await queue.get())

asyncio.run(main())
