# %% [markdown]
# ## task.done

# %%
import asyncio

async def job():
    await asyncio.sleep(1)
    return 'ok'

async def main():
    task = asyncio.create_task(job())
    while not task.done():
        print('waiting')
        await asyncio.sleep(0.2)
    print(task.result())

asyncio.run(main())
