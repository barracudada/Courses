# %% [markdown]
# ## task.exception

# %%
import asyncio

async def bad():
    raise ValueError('boom')

async def main():
    task = asyncio.create_task(bad())
    try:
        await task
    except Exception:
        print(task.exception())

asyncio.run(main())
