# %% [markdown]
# ## get_coro и get_loop

# %%
import asyncio

async def sample():
    task = asyncio.current_task()
    print('Coroutine:', task.get_coro())
    print('Event loop:', task.get_loop())

async def main():
    await asyncio.create_task(sample())

asyncio.run(main())
