# %% [markdown]
# ## get_stack и print_stack

# %%
import asyncio

async def inner():
    task = asyncio.current_task()
    task.print_stack()

async def outer():
    await inner()

async def main():
    await outer()

asyncio.run(main())
