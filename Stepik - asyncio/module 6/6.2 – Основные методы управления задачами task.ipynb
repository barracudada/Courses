# %% [markdown]
# ## done и result

# %%
import asyncio

async def work():
    await asyncio.sleep(1)
    return 5

async def main():
    task = asyncio.create_task(work())
    print(task.done())
    await task
    print(task.result())

asyncio.run(main())
