# %% [markdown]
# ## asyncio.gather

# %%
import asyncio

async def work(n):
    await asyncio.sleep(n)
    return n

async def main():
    results = await asyncio.gather(work(1), work(2), work(3))
    print(results)

asyncio.run(main())
