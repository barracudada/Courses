# %% [markdown]
# ## asyncio.get_running_loop

# %%
import asyncio

async def my_task():
    print('Running task')

async def main():
    loop = asyncio.get_running_loop()
    loop.create_task(my_task())
    await asyncio.sleep(1)

asyncio.run(main())
