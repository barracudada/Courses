# %% [markdown]
# ## Базовые примитивы синхронизации asyncio

# %%
import asyncio

async def main():
    lock = asyncio.Lock()
    event = asyncio.Event()
    semaphore = asyncio.Semaphore(2)
    print(lock, event, semaphore)

asyncio.run(main())
