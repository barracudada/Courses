# %%
import gym # Подключаем игровой модуль gym
import random # Подключаем модель генерации случайных чисел random
import numpy as np # Подключаем модуль numpy
from collections import deque # Подключаем класс deque (очередь) модуля collections
from skimage.color import rgb2gray # Подключаем метод rgb2gray (РГБ в градации серого) библиотеки skimage.color
from skimage.transform import resize # Подключаем метод resize библиотеки skimage.transform
from keras.models import Sequential # Подключаем класс Sequential библиотеки keras.models
from keras.optimizers import RMSprop # Подключаем оптимизатор RMSprop библиотеки keras.optimizers
from keras.layers import Dense, Flatten # Подключаем слои Dense, Flatten библиотеки keras.layers
from keras.layers.convolutional import Conv2D # Подключаем слой Conv2D библиотеки keras.layers.convolutional
from keras import backend as K # Подключаем модуль backend библиотеки keras

# %%
EPISODES = 50000 # Устанавливаем максимальное количество эпизодов

# %%
# Создаем класс агента
class Agent:
    # Инициализация
    def __init__(self, action_size, epsilon):
        self.render = False # Требуется ли рендерить игровой процесс
        self.load_model = False # Требуется ли загружать предобученную модель
        
        self.state_size = (84, 84, 4) # Устанавиваем размеры игрового кадра
        self.action_size = action_size # Получаем количество возможных действий агента
        
        self.epsilon = epsilon # Устанавливаем текущее значение epsilon
        self.epsilon_start, self.epsilon_end = 1.0, 0.1 # Устанавливаем начальное и конечное значение epsilon
        self.exploration_steps = 1000000. # Устанавливаем количество шагов, во время которых будет изменять epsilon
        self.epsilon_decay_step = (self.epsilon_start - self.epsilon_end) \
                                  / self.exploration_steps # Устанавливаем шаг изменения epsilon
        
        self.batch_size = 32 # Устанавливаем размер батча
        self.train_start = 50000 # Устанавливаем количество шагов, после которых начинаем обучение модели        
        self.update_target_rate = 10000 # Устанавливаем количество шагов, после которых обновляем веса второй модели
        self.discount_factor = 0.99 # Устанавливаем коэффициент снижения весов
        self.memory = deque(maxlen=400000) # Создаем объект deque, указывая макстмальное количество элементов
        self.no_op_steps = 30 # Устанавливаем количество шагов, в течении которых вначале эпизода ничего не делаем
        
        self.model = self.build_model() # Создаем основную модель
        self.target_model = self.build_model() # Создаем дублирующую модель
        self.update_target_model() # Обновляем веса дублирующей модели

        self.avg_q_max, self.avg_loss = 0, 0 # Инициализируем среднее вознаграждении и среднюю ошибку
        
        if self.load_model: # Если требуется загрузить веса
            self.model.load_weights("model/breakout_dqn.h5") # Загружаем предобученные веса
    
    # Функция ошибки
    def q_loss(self, y_true, y_pred):
        error = K.abs(y_true - y_pred) # Плучаем модуль разности между предиктом и реальным значением
        q_part = K.clip(error, 0.0, 1.0) # Приводим ошибку error в интервал от 0 до 1
        linear_part = error - q_part # Получаем разницу между ошибкой error и ее clip'ом (все, что вышло за единицу)
        loss = K.mean(0.5 * K.square(q_part) + linear_part) # Считаем среднеквадратичную ошибку и выход за значение единицы
        return loss # Возвращаем loss

    # Строим модель
    def build_model(self):
        model = Sequential()
        model.add(Conv2D(32, (8, 8), strides=(4, 4), activation='relu',
                         input_shape=self.state_size))
        model.add(Conv2D(64, (4, 4), strides=(2, 2), activation='relu'))
        model.add(Conv2D(64, (3, 3), strides=(1, 1), activation='relu'))
        model.add(Flatten())
        model.add(Dense(512, activation='relu'))
        model.add(Dense(self.action_size))
        model.summary()
        model.compile(optimizer = RMSprop(lr=0.00025, epsilon=0.01), loss = self.q_loss)
        return model
        
    # Функция обновления весов дублирующей модели
    def update_target_model(self):
        self.target_model.set_weights(self.model.get_weights()) # Устанавливаем веса дублирующей модели с весов основной

    # Функция получения действия агента
    def get_action(self, history):
        history = np.float32(history / 255.0) # Делим кадр на 255 (нормируем значения)
        if np.random.rand() <= self.epsilon: # Если случайно-сгенерированное число от 0 до 1 меньше текущего epsilon
            return random.randrange(self.action_size) # Возвращаем случайное действие из возможных от 0 до action_size
        else:
            q_value = self.model.predict(history) # Получаем предикт модели по текущему кадру
            return np.argmax(q_value[0]) # Возвращаем индекс максимального вознаграждения

    # Функция записи в память 
    def replay_memory(self, history, action, reward, next_history, dead):
        # Записываем в памть текущий кадр, совершенное действие, полученную награду, следующий кадр и признак завершения партии
        self.memory.append((history, action, reward, next_history, dead)) 

    # Функция обучения модели
    def train_replay(self):
        if len(self.memory) < self.train_start: # Если текущий размер памяти агента меньше установленного train_start
            return # Выходим и не обучаем модель
        if self.epsilon > self.epsilon_end: # Если значение epsilon меньше epsilon_end
            self.epsilon -= self.epsilon_decay_step # меньшаем значение epsilon на epsilon_decay_step

        mini_batch = random.sample(self.memory, self.batch_size) # Получаем из памяти агента случайный батч размером batch_size
        
        # Создаем numpy массив из batch_size-элементов с размерами игрового кадра
        history = np.zeros((self.batch_size, self.state_size[0],
                            self.state_size[1], self.state_size[2]))
        # Создаем numpy массив из batch_size-элементов с размерами игрового кадра
        next_history = np.zeros((self.batch_size, self.state_size[0],
                                 self.state_size[1], self.state_size[2]))
        target = np.zeros((self.batch_size,)) # Создаем numpy массив из batch_size-элементов
        
        action, reward, dead = [], [], [] # Инициализируем списки под действия, награды и признак завершения партии

        for i in range(self.batch_size):
            history[i] = np.float32(mini_batch[i][0] / 255.)
            next_history[i] = np.float32(mini_batch[i][3] / 255.)
            action.append(mini_batch[i][1])
            reward.append(mini_batch[i][2])
            dead.append(mini_batch[i][4])

        target_value = self.target_model.predict(next_history)
        q_value = self.model.predict(history)

        # like Q Learning, get maximum Q value at s'
        # But from target model
        for i in range(self.batch_size):
            if dead[i]:
                target[i] = reward[i]
            else:
                target[i] = reward[i] + self.discount_factor * \
                                        np.amax(target_value[i])
            q_value[i][action[i]] = target[i]
        #loss = self.optimizer([history, action, target])
        loss = self.model.train_on_batch(history, q_value)
        #self.avg_loss += loss[0]
        self.avg_loss += loss

    def save_model(self, name):
        self.model.save_weights(name)

# %%
# 210*160*3(color) --> 84*84(mono)
# float --> integer (to reduce the size of replay memory)
def pre_processing(observe):
    processed_observe = np.uint8(
        resize(rgb2gray(observe), (84, 84), mode='constant') * 255)
    return processed_observe

# %%
# In case of BreakoutDeterministic-v3, always skip 4 frames
# Deterministic-v4 version use 4 actions
env = gym.make('BreakoutDeterministic-v4')
agent = Agent(action_size=3, epsilon = 1)

scores, episodes, global_step = [], [], 0
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 20, 20, 32)        8224
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 9, 9, 64)          32832
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 7, 7, 64)          36928
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 512)               1606144
# _________________________________________________________________
# dense_9 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 1,685,667
# Trainable params: 1,685,667
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_15 (Conv2D)           (None, 20, 20, 32)        8224
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 9, 9, 64)          32832
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 7, 7, 64)          36928
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 512)               1606144
# _________________________________________________________________
# dense_11 (Dense)             (None, 3)                 1539
# =================================================================
# Total params: 1,685,667
# Trainable params: 1,685,667
# Non-trainable params: 0
# _________________________________________________________________

# %%
scores = []
average_scores = []
for e in range(1, EPISODES):
    done = False
    dead = False
    # 1 episode = 5 lives
    step, score, start_life = 0, 0, 5
    observe = env.reset()

    # this is one of DeepMind's idea.
    # just do nothing at the start of episode to avoid sub-optimal
    for _ in range(random.randint(1, agent.no_op_steps)):
        observe, _, _, _ = env.step(1)

    # At start of episode, there is no preceding frame
    # So just copy initial states to make history
    state = pre_processing(observe)
    history = np.stack((state, state, state, state), axis=2)
    history = np.reshape([history], (1, 84, 84, 4))

    while not done:
        if agent.render:
            env.render()
        global_step += 1
        step += 1

        # get action for the current history and go one step in environment
        action = agent.get_action(history)
        # change action to real_action
        if action == 0:
            real_action = 1
        elif action == 1:
            real_action = 2
        else:
            real_action = 3

        observe, reward, done, info = env.step(real_action)
        next_state = pre_processing(observe)
        next_state = np.reshape([next_state], (1, 84, 84, 1))
        next_history = np.append(next_state, history[:, :, :, :3], axis=3)

        agent.avg_q_max += np.amax(
            agent.model.predict(np.float32(history / 255.))[0])

        if start_life > info['ale.lives']:
            dead = True
            start_life = info['ale.lives']

        reward = np.clip(reward, -1., 1.)

        agent.replay_memory(history, action, reward, next_history, dead)
        agent.train_replay()
        if global_step % agent.update_target_rate == 0:
            agent.update_target_model()

        score += reward

        if dead:
            dead = False
        else:
            history = next_history

        if done:            
            if global_step > agent.train_start:                
                stats = [score, agent.avg_q_max / float(step), step,
                          agent.avg_loss / float(step)]
            scores.append(score)
            average_scores.append(agent.avg_q_max / float(step))
            print("ep:", e, "  s.:", int(score), "  mem.len:",
                  len(agent.memory), "  eps:", round(agent.epsilon,2),
                  "  g_step:", global_step, "  av_q:",
                  round(agent.avg_q_max / float(step),3), "  av_loss:",
                  round(agent.avg_loss / float(step),7))

            agent.avg_q_max, agent.avg_loss = 0, 0

    if e % 500 == 0:
        agent.model.save_weights("breakout_dqn.h5")
        np.save('scores', np.array(scores))
        np.save('average_scores', np.array(average_scores))
# Out:
# ep: 1   s.: 2   mem.len: 184   eps: 1   g_step: 184   av_q: 0.012   av_loss: 0.0
# ep: 2   s.: 2   mem.len: 360   eps: 1   g_step: 360   av_q: 0.015   av_loss: 0.0
# ep: 3   s.: 0   mem.len: 482   eps: 1   g_step: 482   av_q: 0.013   av_loss: 0.0
# ep: 4   s.: 0   mem.len: 598   eps: 1   g_step: 598   av_q: 0.013   av_loss: 0.0
# ep: 5   s.: 1   mem.len: 771   eps: 1   g_step: 771   av_q: 0.012   av_loss: 0.0
# ep: 6   s.: 0   mem.len: 887   eps: 1   g_step: 887   av_q: 0.012   av_loss: 0.0
# ep: 7   s.: 1   mem.len: 1042   eps: 1   g_step: 1042   av_q: 0.012   av_loss: 0.0
# ep: 8   s.: 1   mem.len: 1211   eps: 1   g_step: 1211   av_q: 0.012   av_loss: 0.0
# ep: 9   s.: 0   mem.len: 1324   eps: 1   g_step: 1324   av_q: 0.013   av_loss: 0.0
# ep: 10   s.: 0   mem.len: 1425   eps: 1   g_step: 1425   av_q: 0.013   av_loss: 0.0
# ep: 11   s.: 3   mem.len: 1657   eps: 1   g_step: 1657   av_q: 0.015   av_loss: 0.0
# ep: 12   s.: 0   mem.len: 1757   eps: 1   g_step: 1757   av_q: 0.013   av_loss: 0.0
# ep: 13   s.: 3   mem.len: 1968   eps: 1   g_step: 1968   av_q: 0.015   av_loss: 0.0
# ep: 14   s.: 2   mem.len: 2181   eps: 1   g_step: 2181   av_q: 0.012   av_loss: 0.0
# ep: 15   s.: 3   mem.len: 2422   eps: 1   g_step: 2422   av_q: 0.011   av_loss: 0.0
# ep: 16   s.: 2   mem.len: 2624   eps: 1   g_step: 2624   av_q: 0.016   av_loss: 0.0
# ep: 17   s.: 3   mem.len: 2870   eps: 1   g_step: 2870   av_q: 0.012   av_loss: 0.0
# ep: 18   s.: 2   mem.len: 3029   eps: 1   g_step: 3029   av_q: 0.015   av_loss: 0.0
# ep: 19   s.: 0   mem.len: 3133   eps: 1   g_step: 3133   av_q: 0.013   av_loss: 0.0
# ep: 20   s.: 0   mem.len: 3274   eps: 1   g_step: 3274   av_q: 0.013   av_loss: 0.0
# ep: 21   s.: 0   mem.len: 3391   eps: 1   g_step: 3391   av_q: 0.013   av_loss: 0.0
# ep: 22   s.: 2   mem.len: 3567   eps: 1   g_step: 3567   av_q: 0.015   av_loss: 0.0
# ep: 23   s.: 2   mem.len: 3735   eps: 1   g_step: 3735   av_q: 0.01   av_loss: 0.0
# ep: 24   s.: 2   mem.len: 3898   eps: 1   g_step: 3898   av_q: 0.015   av_loss: 0.0
# ep: 25   s.: 5   mem.len: 4214   eps: 1   g_step: 4214   av_q: 0.014   av_loss: 0.0
# ep: 26   s.: 1   mem.len: 4383   eps: 1   g_step: 4383   av_q: 0.012   av_loss: 0.0
# ep: 27   s.: 3   mem.len: 4590   eps: 1   g_step: 4590   av_q: 0.012   av_loss: 0.0
# ep: 28   s.: 0   mem.len: 4711   eps: 1   g_step: 4711   av_q: 0.013   av_loss: 0.0
# ep: 29   s.: 5   mem.len: 5021   eps: 1   g_step: 5021   av_q: 0.009   av_loss: 0.0
# ep: 30   s.: 0   mem.len: 5156   eps: 1   g_step: 5156   av_q: 0.012   av_loss: 0.0
# ep: 31   s.: 0   mem.len: 5274   eps: 1   g_step: 5274   av_q: 0.013   av_loss: 0.0
# ep: 32   s.: 6   mem.len: 5612   eps: 1   g_step: 5612   av_q: 0.017   av_loss: 0.0
# ep: 33   s.: 1   mem.len: 5761   eps: 1   g_step: 5761   av_q: 0.011   av_loss: 0.0
# ep: 34   s.: 2   mem.len: 5948   eps: 1   g_step: 5948   av_q: 0.013   av_loss: 0.0
# ep: 35   s.: 0   mem.len: 6065   eps: 1   g_step: 6065   av_q: 0.013   av_loss: 0.0
# ep: 36   s.: 0   mem.len: 6158   eps: 1   g_step: 6158   av_q: 0.013   av_loss: 0.0
# ep: 37   s.: 0   mem.len: 6287   eps: 1   g_step: 6287   av_q: 0.013   av_loss: 0.0
# ep: 38   s.: 0   mem.len: 6397   eps: 1   g_step: 6397   av_q: 0.013   av_loss: 0.0
# ep: 39   s.: 1   mem.len: 6542   eps: 1   g_step: 6542   av_q: 0.013   av_loss: 0.0
# ep: 40   s.: 1   mem.len: 6703   eps: 1   g_step: 6703   av_q: 0.012   av_loss: 0.0
# ep: 41   s.: 1   mem.len: 6839   eps: 1   g_step: 6839   av_q: 0.013   av_loss: 0.0
# ep: 42   s.: 2   mem.len: 7033   eps: 1   g_step: 7033   av_q: 0.012   av_loss: 0.0
# ep: 43   s.: 1   mem.len: 7177   eps: 1   g_step: 7177   av_q: 0.012   av_loss: 0.0
# ep: 44   s.: 0   mem.len: 7286   eps: 1   g_step: 7286   av_q: 0.012   av_loss: 0.0
# ep: 45   s.: 1   mem.len: 7435   eps: 1   g_step: 7435   av_q: 0.014   av_loss: 0.0
# ep: 46   s.: 0   mem.len: 7536   eps: 1   g_step: 7536   av_q: 0.012   av_loss: 0.0
# ep: 47   s.: 3   mem.len: 7790   eps: 1   g_step: 7790   av_q: 0.01   av_loss: 0.0
# ep: 48   s.: 1   mem.len: 7965   eps: 1   g_step: 7965   av_q: 0.013   av_loss: 0.0
# ep: 49   s.: 2   mem.len: 8116   eps: 1   g_step: 8116   av_q: 0.015   av_loss: 0.0
# ep: 50   s.: 0   mem.len: 8213   eps: 1   g_step: 8213   av_q: 0.013   av_loss: 0.0
# ep: 51   s.: 2   mem.len: 8400   eps: 1   g_step: 8400   av_q: 0.014   av_loss: 0.0
# ep: 52   s.: 0   mem.len: 8517   eps: 1   g_step: 8517   av_q: 0.012   av_loss: 0.0
# ep: 53   s.: 1   mem.len: 8684   eps: 1   g_step: 8684   av_q: 0.013   av_loss: 0.0
# ep: 54   s.: 1   mem.len: 8820   eps: 1   g_step: 8820   av_q: 0.014   av_loss: 0.0
# ep: 55   s.: 2   mem.len: 8999   eps: 1   g_step: 8999   av_q: 0.015   av_loss: 0.0
# ep: 56   s.: 2   mem.len: 9222   eps: 1   g_step: 9222   av_q: 0.012   av_loss: 0.0
# ep: 57   s.: 2   mem.len: 9375   eps: 1   g_step: 9375   av_q: 0.016   av_loss: 0.0
# ep: 58   s.: 0   mem.len: 9477   eps: 1   g_step: 9477   av_q: 0.012   av_loss: 0.0
# ep: 59   s.: 1   mem.len: 9623   eps: 1   g_step: 9623   av_q: 0.014   av_loss: 0.0
# ep: 60   s.: 1   mem.len: 9785   eps: 1   g_step: 9785   av_q: 0.012   av_loss: 0.0
# ep: 61   s.: 2   mem.len: 9959   eps: 1   g_step: 9959   av_q: 0.015   av_loss: 0.0
# ep: 62   s.: 5   mem.len: 10281   eps: 1   g_step: 10281   av_q: 0.012   av_loss: 0.0
# ep: 63   s.: 0   mem.len: 10387   eps: 1   g_step: 10387   av_q: 0.012   av_loss: 0.0
# ep: 64   s.: 0   mem.len: 10501   eps: 1   g_step: 10501   av_q: 0.012   av_loss: 0.0
# ep: 65   s.: 0   mem.len: 10620   eps: 1   g_step: 10620   av_q: 0.013   av_loss: 0.0
# ep: 66   s.: 3   mem.len: 10859   eps: 1   g_step: 10859   av_q: 0.013   av_loss: 0.0
# ep: 67   s.: 0   mem.len: 10982   eps: 1   g_step: 10982   av_q: 0.013   av_loss: 0.0
# ep: 68   s.: 2   mem.len: 11214   eps: 1   g_step: 11214   av_q: 0.012   av_loss: 0.0
# ep: 69   s.: 0   mem.len: 11328   eps: 1   g_step: 11328   av_q: 0.013   av_loss: 0.0
# ep: 70   s.: 1   mem.len: 11470   eps: 1   g_step: 11470   av_q: 0.013   av_loss: 0.0
# ep: 71   s.: 2   mem.len: 11690   eps: 1   g_step: 11690   av_q: 0.012   av_loss: 0.0
# ep: 72   s.: 1   mem.len: 11845   eps: 1   g_step: 11845   av_q: 0.012   av_loss: 0.0
# ep: 73   s.: 1   mem.len: 11983   eps: 1   g_step: 11983   av_q: 0.014   av_loss: 0.0
# ep: 74   s.: 2   mem.len: 12175   eps: 1   g_step: 12175   av_q: 0.012   av_loss: 0.0
# ep: 75   s.: 1   mem.len: 12340   eps: 1   g_step: 12340   av_q: 0.014   av_loss: 0.0
# ep: 76   s.: 2   mem.len: 12525   eps: 1   g_step: 12525   av_q: 0.016   av_loss: 0.0
# ep: 77   s.: 1   mem.len: 12695   eps: 1   g_step: 12695   av_q: 0.012   av_loss: 0.0
# ep: 78   s.: 3   mem.len: 12943   eps: 1   g_step: 12943   av_q: 0.009   av_loss: 0.0
# ep: 79   s.: 1   mem.len: 13104   eps: 1   g_step: 13104   av_q: 0.012   av_loss: 0.0
# ep: 80   s.: 3   mem.len: 13324   eps: 1   g_step: 13324   av_q: 0.016   av_loss: 0.0
# ep: 81   s.: 0   mem.len: 13434   eps: 1   g_step: 13434   av_q: 0.012   av_loss: 0.0
# ep: 82   s.: 3   mem.len: 13657   eps: 1   g_step: 13657   av_q: 0.013   av_loss: 0.0
# ep: 83   s.: 0   mem.len: 13784   eps: 1   g_step: 13784   av_q: 0.013   av_loss: 0.0
# ep: 84   s.: 1   mem.len: 13913   eps: 1   g_step: 13913   av_q: 0.014   av_loss: 0.0
# ep: 85   s.: 0   mem.len: 14039   eps: 1   g_step: 14039   av_q: 0.013   av_loss: 0.0
# ep: 86   s.: 0   mem.len: 14158   eps: 1   g_step: 14158   av_q: 0.013   av_loss: 0.0
# ep: 87   s.: 1   mem.len: 14305   eps: 1   g_step: 14305   av_q: 0.012   av_loss: 0.0
# ep: 88   s.: 2   mem.len: 14486   eps: 1   g_step: 14486   av_q: 0.016   av_loss: 0.0
# ep: 89   s.: 2   mem.len: 14664   eps: 1   g_step: 14664   av_q: 0.013   av_loss: 0.0
# ep: 90   s.: 4   mem.len: 14958   eps: 1   g_step: 14958   av_q: 0.012   av_loss: 0.0
# ep: 91   s.: 0   mem.len: 15077   eps: 1   g_step: 15077   av_q: 0.013   av_loss: 0.0
# ep: 92   s.: 0   mem.len: 15195   eps: 1   g_step: 15195   av_q: 0.012   av_loss: 0.0
# ep: 93   s.: 0   mem.len: 15305   eps: 1   g_step: 15305   av_q: 0.013   av_loss: 0.0
# ep: 94   s.: 3   mem.len: 15524   eps: 1   g_step: 15524   av_q: 0.012   av_loss: 0.0
# ep: 95   s.: 1   mem.len: 15685   eps: 1   g_step: 15685   av_q: 0.015   av_loss: 0.0
# ep: 96   s.: 1   mem.len: 15846   eps: 1   g_step: 15846   av_q: 0.012   av_loss: 0.0
# ep: 97   s.: 1   mem.len: 15989   eps: 1   g_step: 15989   av_q: 0.013   av_loss: 0.0
# ep: 98   s.: 4   mem.len: 16257   eps: 1   g_step: 16257   av_q: 0.016   av_loss: 0.0
# ep: 99   s.: 2   mem.len: 16441   eps: 1   g_step: 16441   av_q: 0.011   av_loss: 0.0
# ep: 100   s.: 1   mem.len: 16571   eps: 1   g_step: 16571   av_q: 0.013   av_loss: 0.0
# ep: 101   s.: 1   mem.len: 16714   eps: 1   g_step: 16714   av_q: 0.014   av_loss: 0.0
# ep: 102   s.: 2   mem.len: 16884   eps: 1   g_step: 16884   av_q: 0.013   av_loss: 0.0
# ep: 103   s.: 2   mem.len: 17082   eps: 1   g_step: 17082   av_q: 0.013   av_loss: 0.0
# ep: 104   s.: 1   mem.len: 17235   eps: 1   g_step: 17235   av_q: 0.014   av_loss: 0.0
# ep: 105   s.: 0   mem.len: 17343   eps: 1   g_step: 17343   av_q: 0.013   av_loss: 0.0
# ep: 106   s.: 0   mem.len: 17452   eps: 1   g_step: 17452   av_q: 0.013   av_loss: 0.0
# ep: 107   s.: 0   mem.len: 17556   eps: 1   g_step: 17556   av_q: 0.013   av_loss: 0.0
# ep: 108   s.: 0   mem.len: 17651   eps: 1   g_step: 17651   av_q: 0.013   av_loss: 0.0
# ep: 109   s.: 1   mem.len: 17810   eps: 1   g_step: 17810   av_q: 0.014   av_loss: 0.0
# ep: 110   s.: 1   mem.len: 17933   eps: 1   g_step: 17933   av_q: 0.013   av_loss: 0.0
# ep: 111   s.: 2   mem.len: 18158   eps: 1   g_step: 18158   av_q: 0.012   av_loss: 0.0
# ep: 112   s.: 0   mem.len: 18273   eps: 1   g_step: 18273   av_q: 0.013   av_loss: 0.0
# ep: 113   s.: 0   mem.len: 18376   eps: 1   g_step: 18376   av_q: 0.013   av_loss: 0.0
# ep: 114   s.: 1   mem.len: 18532   eps: 1   g_step: 18532   av_q: 0.014   av_loss: 0.0
# ep: 115   s.: 1   mem.len: 18679   eps: 1   g_step: 18679   av_q: 0.013   av_loss: 0.0
# ep: 116   s.: 0   mem.len: 18801   eps: 1   g_step: 18801   av_q: 0.013   av_loss: 0.0
# ep: 117   s.: 0   mem.len: 18898   eps: 1   g_step: 18898   av_q: 0.013   av_loss: 0.0
# ep: 118   s.: 1   mem.len: 19061   eps: 1   g_step: 19061   av_q: 0.015   av_loss: 0.0
# ep: 119   s.: 2   mem.len: 19249   eps: 1   g_step: 19249   av_q: 0.016   av_loss: 0.0
# ep: 120   s.: 2   mem.len: 19445   eps: 1   g_step: 19445   av_q: 0.016   av_loss: 0.0
# ep: 121   s.: 1   mem.len: 19592   eps: 1   g_step: 19592   av_q: 0.014   av_loss: 0.0
# ep: 122   s.: 2   mem.len: 19805   eps: 1   g_step: 19805   av_q: 0.011   av_loss: 0.0
# ep: 123   s.: 0   mem.len: 19923   eps: 1   g_step: 19923   av_q: 0.012   av_loss: 0.0
# ep: 124   s.: 3   mem.len: 20182   eps: 1   g_step: 20182   av_q: 0.013   av_loss: 0.0
# ep: 125   s.: 0   mem.len: 20281   eps: 1   g_step: 20281   av_q: 0.013   av_loss: 0.0
# ep: 126   s.: 2   mem.len: 20495   eps: 1   g_step: 20495   av_q: 0.012   av_loss: 0.0
# ep: 127   s.: 0   mem.len: 20601   eps: 1   g_step: 20601   av_q: 0.013   av_loss: 0.0
# ep: 128   s.: 2   mem.len: 20789   eps: 1   g_step: 20789   av_q: 0.012   av_loss: 0.0
# ep: 129   s.: 0   mem.len: 20916   eps: 1   g_step: 20916   av_q: 0.012   av_loss: 0.0
# ep: 130   s.: 2   mem.len: 21117   eps: 1   g_step: 21117   av_q: 0.012   av_loss: 0.0
# ep: 131   s.: 2   mem.len: 21287   eps: 1   g_step: 21287   av_q: 0.016   av_loss: 0.0
# ep: 132   s.: 1   mem.len: 21445   eps: 1   g_step: 21445   av_q: 0.013   av_loss: 0.0
# ep: 133   s.: 0   mem.len: 21546   eps: 1   g_step: 21546   av_q: 0.013   av_loss: 0.0
# ep: 134   s.: 0   mem.len: 21674   eps: 1   g_step: 21674   av_q: 0.013   av_loss: 0.0
# ep: 135   s.: 0   mem.len: 21771   eps: 1   g_step: 21771   av_q: 0.013   av_loss: 0.0
# ep: 136   s.: 0   mem.len: 21877   eps: 1   g_step: 21877   av_q: 0.013   av_loss: 0.0
# ep: 137   s.: 2   mem.len: 22080   eps: 1   g_step: 22080   av_q: 0.012   av_loss: 0.0
# ep: 138   s.: 0   mem.len: 22213   eps: 1   g_step: 22213   av_q: 0.013   av_loss: 0.0
# ep: 139   s.: 2   mem.len: 22421   eps: 1   g_step: 22421   av_q: 0.013   av_loss: 0.0
# ep: 140   s.: 1   mem.len: 22567   eps: 1   g_step: 22567   av_q: 0.012   av_loss: 0.0
# ep: 141   s.: 1   mem.len: 22721   eps: 1   g_step: 22721   av_q: 0.013   av_loss: 0.0
# ep: 142   s.: 1   mem.len: 22885   eps: 1   g_step: 22885   av_q: 0.012   av_loss: 0.0
# ep: 143   s.: 1   mem.len: 23038   eps: 1   g_step: 23038   av_q: 0.012   av_loss: 0.0
# ep: 144   s.: 0   mem.len: 23147   eps: 1   g_step: 23147   av_q: 0.013   av_loss: 0.0
# ep: 145   s.: 0   mem.len: 23254   eps: 1   g_step: 23254   av_q: 0.013   av_loss: 0.0
# ep: 146   s.: 0   mem.len: 23375   eps: 1   g_step: 23375   av_q: 0.013   av_loss: 0.0
# ep: 147   s.: 0   mem.len: 23491   eps: 1   g_step: 23491   av_q: 0.012   av_loss: 0.0
# ep: 148   s.: 1   mem.len: 23646   eps: 1   g_step: 23646   av_q: 0.011   av_loss: 0.0
# ep: 149   s.: 0   mem.len: 23764   eps: 1   g_step: 23764   av_q: 0.012   av_loss: 0.0
# ep: 150   s.: 2   mem.len: 23938   eps: 1   g_step: 23938   av_q: 0.015   av_loss: 0.0
# ep: 151   s.: 3   mem.len: 24158   eps: 1   g_step: 24158   av_q: 0.011   av_loss: 0.0
# ep: 152   s.: 1   mem.len: 24319   eps: 1   g_step: 24319   av_q: 0.014   av_loss: 0.0
# ep: 153   s.: 1   mem.len: 24485   eps: 1   g_step: 24485   av_q: 0.013   av_loss: 0.0
# ep: 154   s.: 0   mem.len: 24579   eps: 1   g_step: 24579   av_q: 0.013   av_loss: 0.0
# ep: 155   s.: 1   mem.len: 24748   eps: 1   g_step: 24748   av_q: 0.015   av_loss: 0.0
# ep: 156   s.: 0   mem.len: 24867   eps: 1   g_step: 24867   av_q: 0.013   av_loss: 0.0
# ep: 157   s.: 0   mem.len: 24981   eps: 1   g_step: 24981   av_q: 0.012   av_loss: 0.0
# ep: 158   s.: 0   mem.len: 25086   eps: 1   g_step: 25086   av_q: 0.012   av_loss: 0.0
# ep: 159   s.: 2   mem.len: 25310   eps: 1   g_step: 25310   av_q: 0.012   av_loss: 0.0
# ep: 160   s.: 1   mem.len: 25460   eps: 1   g_step: 25460   av_q: 0.014   av_loss: 0.0
# ep: 161   s.: 1   mem.len: 25613   eps: 1   g_step: 25613   av_q: 0.012   av_loss: 0.0
# ep: 162   s.: 1   mem.len: 25782   eps: 1   g_step: 25782   av_q: 0.012   av_loss: 0.0
# ep: 163   s.: 0   mem.len: 25879   eps: 1   g_step: 25879   av_q: 0.013   av_loss: 0.0
# ep: 164   s.: 2   mem.len: 26075   eps: 1   g_step: 26075   av_q: 0.015   av_loss: 0.0
# ep: 165   s.: 0   mem.len: 26200   eps: 1   g_step: 26200   av_q: 0.013   av_loss: 0.0
# ep: 166   s.: 0   mem.len: 26312   eps: 1   g_step: 26312   av_q: 0.013   av_loss: 0.0
# ep: 167   s.: 1   mem.len: 26463   eps: 1   g_step: 26463   av_q: 0.011   av_loss: 0.0
# ep: 168   s.: 0   mem.len: 26582   eps: 1   g_step: 26582   av_q: 0.013   av_loss: 0.0
# ep: 169   s.: 2   mem.len: 26757   eps: 1   g_step: 26757   av_q: 0.013   av_loss: 0.0
# ep: 170   s.: 2   mem.len: 26941   eps: 1   g_step: 26941   av_q: 0.016   av_loss: 0.0
# ep: 171   s.: 3   mem.len: 27168   eps: 1   g_step: 27168   av_q: 0.011   av_loss: 0.0
# ep: 172   s.: 0   mem.len: 27293   eps: 1   g_step: 27293   av_q: 0.013   av_loss: 0.0
# ep: 173   s.: 3   mem.len: 27499   eps: 1   g_step: 27499   av_q: 0.014   av_loss: 0.0
# ep: 174   s.: 1   mem.len: 27648   eps: 1   g_step: 27648   av_q: 0.015   av_loss: 0.0
# ep: 175   s.: 2   mem.len: 27826   eps: 1   g_step: 27826   av_q: 0.012   av_loss: 0.0
# ep: 176   s.: 0   mem.len: 27945   eps: 1   g_step: 27945   av_q: 0.013   av_loss: 0.0
# ep: 177   s.: 3   mem.len: 28162   eps: 1   g_step: 28162   av_q: 0.014   av_loss: 0.0
# ep: 178   s.: 3   mem.len: 28375   eps: 1   g_step: 28375   av_q: 0.015   av_loss: 0.0
# ep: 179   s.: 2   mem.len: 28574   eps: 1   g_step: 28574   av_q: 0.013   av_loss: 0.0
# ep: 180   s.: 1   mem.len: 28712   eps: 1   g_step: 28712   av_q: 0.015   av_loss: 0.0
# ep: 181   s.: 1   mem.len: 28858   eps: 1   g_step: 28858   av_q: 0.012   av_loss: 0.0
# ep: 182   s.: 3   mem.len: 29080   eps: 1   g_step: 29080   av_q: 0.016   av_loss: 0.0
# ep: 183   s.: 2   mem.len: 29262   eps: 1   g_step: 29262   av_q: 0.015   av_loss: 0.0
# ep: 184   s.: 1   mem.len: 29412   eps: 1   g_step: 29412   av_q: 0.012   av_loss: 0.0
# ep: 185   s.: 3   mem.len: 29632   eps: 1   g_step: 29632   av_q: 0.011   av_loss: 0.0
# ep: 186   s.: 0   mem.len: 29732   eps: 1   g_step: 29732   av_q: 0.013   av_loss: 0.0
# ep: 187   s.: 1   mem.len: 29893   eps: 1   g_step: 29893   av_q: 0.014   av_loss: 0.0
# ep: 188   s.: 1   mem.len: 30036   eps: 1   g_step: 30036   av_q: 0.012   av_loss: 0.0
# ep: 189   s.: 0   mem.len: 30130   eps: 1   g_step: 30130   av_q: 0.013   av_loss: 0.0
# ep: 190   s.: 2   mem.len: 30357   eps: 1   g_step: 30357   av_q: 0.011   av_loss: 0.0
# ep: 191   s.: 1   mem.len: 30506   eps: 1   g_step: 30506   av_q: 0.013   av_loss: 0.0
# ep: 192   s.: 0   mem.len: 30623   eps: 1   g_step: 30623   av_q: 0.013   av_loss: 0.0
# ep: 193   s.: 2   mem.len: 30817   eps: 1   g_step: 30817   av_q: 0.016   av_loss: 0.0
# ep: 194   s.: 0   mem.len: 30913   eps: 1   g_step: 30913   av_q: 0.013   av_loss: 0.0
# ep: 195   s.: 1   mem.len: 31055   eps: 1   g_step: 31055   av_q: 0.013   av_loss: 0.0
# ep: 196   s.: 0   mem.len: 31168   eps: 1   g_step: 31168   av_q: 0.013   av_loss: 0.0
# ep: 197   s.: 0   mem.len: 31273   eps: 1   g_step: 31273   av_q: 0.012   av_loss: 0.0
# ep: 198   s.: 3   mem.len: 31496   eps: 1   g_step: 31496   av_q: 0.013   av_loss: 0.0
# ep: 199   s.: 3   mem.len: 31701   eps: 1   g_step: 31701   av_q: 0.014   av_loss: 0.0
# ep: 200   s.: 2   mem.len: 31919   eps: 1   g_step: 31919   av_q: 0.012   av_loss: 0.0
# ep: 201   s.: 1   mem.len: 32057   eps: 1   g_step: 32057   av_q: 0.014   av_loss: 0.0
# ep: 202   s.: 2   mem.len: 32241   eps: 1   g_step: 32241   av_q: 0.012   av_loss: 0.0
# ep: 203   s.: 2   mem.len: 32436   eps: 1   g_step: 32436   av_q: 0.013   av_loss: 0.0
# ep: 204   s.: 2   mem.len: 32617   eps: 1   g_step: 32617   av_q: 0.016   av_loss: 0.0
# ep: 205   s.: 1   mem.len: 32761   eps: 1   g_step: 32761   av_q: 0.012   av_loss: 0.0
# ep: 206   s.: 0   mem.len: 32860   eps: 1   g_step: 32860   av_q: 0.012   av_loss: 0.0
# ep: 207   s.: 2   mem.len: 33055   eps: 1   g_step: 33055   av_q: 0.013   av_loss: 0.0
# ep: 208   s.: 0   mem.len: 33172   eps: 1   g_step: 33172   av_q: 0.013   av_loss: 0.0
# ep: 209   s.: 0   mem.len: 33290   eps: 1   g_step: 33290   av_q: 0.013   av_loss: 0.0
# ep: 210   s.: 1   mem.len: 33421   eps: 1   g_step: 33421   av_q: 0.015   av_loss: 0.0
# ep: 211   s.: 1   mem.len: 33576   eps: 1   g_step: 33576   av_q: 0.013   av_loss: 0.0
# ep: 212   s.: 0   mem.len: 33696   eps: 1   g_step: 33696   av_q: 0.013   av_loss: 0.0
# ep: 213   s.: 1   mem.len: 33837   eps: 1   g_step: 33837   av_q: 0.012   av_loss: 0.0
# ep: 214   s.: 3   mem.len: 34096   eps: 1   g_step: 34096   av_q: 0.012   av_loss: 0.0
# ep: 215   s.: 2   mem.len: 34292   eps: 1   g_step: 34292   av_q: 0.014   av_loss: 0.0
# ep: 216   s.: 4   mem.len: 34608   eps: 1   g_step: 34608   av_q: 0.007   av_loss: 0.0
# ep: 217   s.: 1   mem.len: 34765   eps: 1   g_step: 34765   av_q: 0.013   av_loss: 0.0
# ep: 218   s.: 0   mem.len: 34876   eps: 1   g_step: 34876   av_q: 0.013   av_loss: 0.0
# ep: 219   s.: 1   mem.len: 35029   eps: 1   g_step: 35029   av_q: 0.011   av_loss: 0.0
# ep: 220   s.: 1   mem.len: 35175   eps: 1   g_step: 35175   av_q: 0.015   av_loss: 0.0
# ep: 221   s.: 1   mem.len: 35322   eps: 1   g_step: 35322   av_q: 0.012   av_loss: 0.0
# ep: 222   s.: 1   mem.len: 35469   eps: 1   g_step: 35469   av_q: 0.012   av_loss: 0.0
# ep: 223   s.: 0   mem.len: 35599   eps: 1   g_step: 35599   av_q: 0.013   av_loss: 0.0
# ep: 224   s.: 3   mem.len: 35847   eps: 1   g_step: 35847   av_q: 0.012   av_loss: 0.0
# ep: 225   s.: 2   mem.len: 36068   eps: 1   g_step: 36068   av_q: 0.013   av_loss: 0.0
# ep: 226   s.: 0   mem.len: 36185   eps: 1   g_step: 36185   av_q: 0.013   av_loss: 0.0
# ep: 227   s.: 1   mem.len: 36346   eps: 1   g_step: 36346   av_q: 0.011   av_loss: 0.0
# ep: 228   s.: 0   mem.len: 36452   eps: 1   g_step: 36452   av_q: 0.013   av_loss: 0.0
# ep: 229   s.: 0   mem.len: 36545   eps: 1   g_step: 36545   av_q: 0.013   av_loss: 0.0
# ep: 230   s.: 1   mem.len: 36695   eps: 1   g_step: 36695   av_q: 0.014   av_loss: 0.0
# ep: 231   s.: 1   mem.len: 36858   eps: 1   g_step: 36858   av_q: 0.013   av_loss: 0.0
# ep: 232   s.: 3   mem.len: 37079   eps: 1   g_step: 37079   av_q: 0.013   av_loss: 0.0
# ep: 233   s.: 2   mem.len: 37250   eps: 1   g_step: 37250   av_q: 0.013   av_loss: 0.0
# ep: 234   s.: 0   mem.len: 37362   eps: 1   g_step: 37362   av_q: 0.013   av_loss: 0.0
# ep: 235   s.: 2   mem.len: 37549   eps: 1   g_step: 37549   av_q: 0.012   av_loss: 0.0
# ep: 236   s.: 2   mem.len: 37740   eps: 1   g_step: 37740   av_q: 0.013   av_loss: 0.0
# ep: 237   s.: 1   mem.len: 37907   eps: 1   g_step: 37907   av_q: 0.013   av_loss: 0.0
# ep: 238   s.: 2   mem.len: 38109   eps: 1   g_step: 38109   av_q: 0.016   av_loss: 0.0
# ep: 239   s.: 0   mem.len: 38217   eps: 1   g_step: 38217   av_q: 0.012   av_loss: 0.0
# ep: 240   s.: 4   mem.len: 38493   eps: 1   g_step: 38493   av_q: 0.011   av_loss: 0.0
# ep: 241   s.: 2   mem.len: 38681   eps: 1   g_step: 38681   av_q: 0.015   av_loss: 0.0
# ep: 242   s.: 0   mem.len: 38798   eps: 1   g_step: 38798   av_q: 0.013   av_loss: 0.0
# ep: 243   s.: 1   mem.len: 38956   eps: 1   g_step: 38956   av_q: 0.014   av_loss: 0.0
# ep: 244   s.: 0   mem.len: 39080   eps: 1   g_step: 39080   av_q: 0.013   av_loss: 0.0
# ep: 245   s.: 0   mem.len: 39198   eps: 1   g_step: 39198   av_q: 0.012   av_loss: 0.0
# ep: 246   s.: 2   mem.len: 39404   eps: 1   g_step: 39404   av_q: 0.013   av_loss: 0.0
# ep: 247   s.: 1   mem.len: 39546   eps: 1   g_step: 39546   av_q: 0.012   av_loss: 0.0
# ep: 248   s.: 1   mem.len: 39700   eps: 1   g_step: 39700   av_q: 0.012   av_loss: 0.0
# ep: 249   s.: 1   mem.len: 39850   eps: 1   g_step: 39850   av_q: 0.013   av_loss: 0.0
# ep: 250   s.: 1   mem.len: 39991   eps: 1   g_step: 39991   av_q: 0.014   av_loss: 0.0
# ep: 251   s.: 1   mem.len: 40170   eps: 1   g_step: 40170   av_q: 0.013   av_loss: 0.0
# ep: 252   s.: 2   mem.len: 40398   eps: 1   g_step: 40398   av_q: 0.013   av_loss: 0.0
# ep: 253   s.: 0   mem.len: 40500   eps: 1   g_step: 40500   av_q: 0.013   av_loss: 0.0
# ep: 254   s.: 2   mem.len: 40701   eps: 1   g_step: 40701   av_q: 0.014   av_loss: 0.0
# ep: 255   s.: 2   mem.len: 40902   eps: 1   g_step: 40902   av_q: 0.016   av_loss: 0.0
# ep: 256   s.: 1   mem.len: 41029   eps: 1   g_step: 41029   av_q: 0.014   av_loss: 0.0
# ep: 257   s.: 3   mem.len: 41283   eps: 1   g_step: 41283   av_q: 0.011   av_loss: 0.0
# ep: 258   s.: 0   mem.len: 41400   eps: 1   g_step: 41400   av_q: 0.013   av_loss: 0.0
# ep: 259   s.: 0   mem.len: 41501   eps: 1   g_step: 41501   av_q: 0.013   av_loss: 0.0
# ep: 260   s.: 1   mem.len: 41657   eps: 1   g_step: 41657   av_q: 0.012   av_loss: 0.0
# ep: 261   s.: 1   mem.len: 41820   eps: 1   g_step: 41820   av_q: 0.013   av_loss: 0.0
# ep: 262   s.: 0   mem.len: 41940   eps: 1   g_step: 41940   av_q: 0.012   av_loss: 0.0
# ep: 263   s.: 0   mem.len: 42040   eps: 1   g_step: 42040   av_q: 0.013   av_loss: 0.0
# ep: 264   s.: 1   mem.len: 42187   eps: 1   g_step: 42187   av_q: 0.015   av_loss: 0.0
# ep: 265   s.: 1   mem.len: 42340   eps: 1   g_step: 42340   av_q: 0.015   av_loss: 0.0
# ep: 266   s.: 2   mem.len: 42536   eps: 1   g_step: 42536   av_q: 0.012   av_loss: 0.0
# ep: 267   s.: 0   mem.len: 42655   eps: 1   g_step: 42655   av_q: 0.012   av_loss: 0.0
# ep: 268   s.: 2   mem.len: 42838   eps: 1   g_step: 42838   av_q: 0.012   av_loss: 0.0
# ep: 269   s.: 3   mem.len: 43063   eps: 1   g_step: 43063   av_q: 0.013   av_loss: 0.0
# ep: 270   s.: 1   mem.len: 43214   eps: 1   g_step: 43214   av_q: 0.013   av_loss: 0.0
# ep: 271   s.: 1   mem.len: 43354   eps: 1   g_step: 43354   av_q: 0.014   av_loss: 0.0
# ep: 272   s.: 1   mem.len: 43487   eps: 1   g_step: 43487   av_q: 0.013   av_loss: 0.0
# ep: 273   s.: 0   mem.len: 43585   eps: 1   g_step: 43585   av_q: 0.012   av_loss: 0.0
# ep: 274   s.: 3   mem.len: 43829   eps: 1   g_step: 43829   av_q: 0.008   av_loss: 0.0
# ep: 275   s.: 0   mem.len: 43946   eps: 1   g_step: 43946   av_q: 0.013   av_loss: 0.0
# ep: 276   s.: 2   mem.len: 44123   eps: 1   g_step: 44123   av_q: 0.012   av_loss: 0.0
# ep: 277   s.: 1   mem.len: 44258   eps: 1   g_step: 44258   av_q: 0.014   av_loss: 0.0
# ep: 278   s.: 0   mem.len: 44355   eps: 1   g_step: 44355   av_q: 0.013   av_loss: 0.0
# ep: 279   s.: 0   mem.len: 44464   eps: 1   g_step: 44464   av_q: 0.013   av_loss: 0.0
# ep: 280   s.: 0   mem.len: 44584   eps: 1   g_step: 44584   av_q: 0.012   av_loss: 0.0
# ep: 281   s.: 2   mem.len: 44773   eps: 1   g_step: 44773   av_q: 0.012   av_loss: 0.0
# ep: 282   s.: 0   mem.len: 44898   eps: 1   g_step: 44898   av_q: 0.013   av_loss: 0.0
# ep: 283   s.: 2   mem.len: 45091   eps: 1   g_step: 45091   av_q: 0.013   av_loss: 0.0
# ep: 284   s.: 0   mem.len: 45204   eps: 1   g_step: 45204   av_q: 0.012   av_loss: 0.0
# ep: 285   s.: 2   mem.len: 45406   eps: 1   g_step: 45406   av_q: 0.012   av_loss: 0.0
# ep: 286   s.: 3   mem.len: 45639   eps: 1   g_step: 45639   av_q: 0.012   av_loss: 0.0
# ep: 287   s.: 2   mem.len: 45820   eps: 1   g_step: 45820   av_q: 0.012   av_loss: 0.0
# ep: 288   s.: 2   mem.len: 45996   eps: 1   g_step: 45996   av_q: 0.015   av_loss: 0.0
# ep: 289   s.: 0   mem.len: 46104   eps: 1   g_step: 46104   av_q: 0.013   av_loss: 0.0
# ep: 290   s.: 2   mem.len: 46292   eps: 1   g_step: 46292   av_q: 0.016   av_loss: 0.0
# ep: 291   s.: 2   mem.len: 46489   eps: 1   g_step: 46489   av_q: 0.013   av_loss: 0.0
# ep: 292   s.: 5   mem.len: 46803   eps: 1   g_step: 46803   av_q: 0.012   av_loss: 0.0
# ep: 293   s.: 3   mem.len: 47039   eps: 1   g_step: 47039   av_q: 0.012   av_loss: 0.0
# ep: 294   s.: 0   mem.len: 47151   eps: 1   g_step: 47151   av_q: 0.012   av_loss: 0.0
# ep: 295   s.: 1   mem.len: 47306   eps: 1   g_step: 47306   av_q: 0.014   av_loss: 0.0
# ep: 296   s.: 1   mem.len: 47453   eps: 1   g_step: 47453   av_q: 0.012   av_loss: 0.0
# ep: 297   s.: 1   mem.len: 47609   eps: 1   g_step: 47609   av_q: 0.013   av_loss: 0.0
# ep: 298   s.: 2   mem.len: 47802   eps: 1   g_step: 47802   av_q: 0.01   av_loss: 0.0
# ep: 299   s.: 3   mem.len: 48059   eps: 1   g_step: 48059   av_q: 0.013   av_loss: 0.0
# ep: 300   s.: 3   mem.len: 48266   eps: 1   g_step: 48266   av_q: 0.016   av_loss: 0.0
# ep: 301   s.: 0   mem.len: 48388   eps: 1   g_step: 48388   av_q: 0.013   av_loss: 0.0
# ep: 302   s.: 0   mem.len: 48495   eps: 1   g_step: 48495   av_q: 0.013   av_loss: 0.0
# ep: 303   s.: 2   mem.len: 48694   eps: 1   g_step: 48694   av_q: 0.011   av_loss: 0.0
# ep: 304   s.: 1   mem.len: 48851   eps: 1   g_step: 48851   av_q: 0.013   av_loss: 0.0
# ep: 305   s.: 3   mem.len: 49077   eps: 1   g_step: 49077   av_q: 0.012   av_loss: 0.0
# ep: 306   s.: 3   mem.len: 49263   eps: 1   g_step: 49263   av_q: 0.015   av_loss: 0.0
# ep: 307   s.: 1   mem.len: 49398   eps: 1   g_step: 49398   av_q: 0.013   av_loss: 0.0
# ep: 308   s.: 1   mem.len: 49550   eps: 1   g_step: 49550   av_q: 0.014   av_loss: 0.0
# ep: 309   s.: 0   mem.len: 49678   eps: 1   g_step: 49678   av_q: 0.013   av_loss: 0.0
# ep: 310   s.: 2   mem.len: 49876   eps: 1   g_step: 49876   av_q: 0.012   av_loss: 0.0
# ep: 311   s.: 2   mem.len: 50064   eps: 1.0   g_step: 50064   av_q: 0.012   av_loss: 0.0003059
# ep: 312   s.: 0   mem.len: 50185   eps: 1.0   g_step: 50185   av_q: 0.025   av_loss: 0.001589
# ep: 313   s.: 1   mem.len: 50326   eps: 1.0   g_step: 50326   av_q: 0.023   av_loss: 0.0011419
# ep: 314   s.: 1   mem.len: 50496   eps: 1.0   g_step: 50496   av_q: 0.021   av_loss: 0.0007998
# ep: 315   s.: 0   mem.len: 50591   eps: 1.0   g_step: 50591   av_q: 0.023   av_loss: 0.0012034
# ep: 316   s.: 2   mem.len: 50777   eps: 1.0   g_step: 50777   av_q: 0.026   av_loss: 0.0014215
# ep: 317   s.: 0   mem.len: 50871   eps: 1.0   g_step: 50871   av_q: 0.026   av_loss: 0.0015452
# ep: 318   s.: 2   mem.len: 51060   eps: 1.0   g_step: 51060   av_q: 0.022   av_loss: 0.0010757
# ep: 319   s.: 0   mem.len: 51159   eps: 1.0   g_step: 51159   av_q: 0.021   av_loss: 0.0011019
# ep: 320   s.: 0   mem.len: 51286   eps: 1.0   g_step: 51286   av_q: 0.022   av_loss: 0.0012658
# ep: 321   s.: 2   mem.len: 51472   eps: 1.0   g_step: 51472   av_q: 0.021   av_loss: 0.0009788
# ep: 322   s.: 1   mem.len: 51647   eps: 1.0   g_step: 51647   av_q: 0.024   av_loss: 0.001249
# ep: 323   s.: 2   mem.len: 51842   eps: 1.0   g_step: 51842   av_q: 0.023   av_loss: 0.0011448
# ep: 324   s.: 0   mem.len: 51937   eps: 1.0   g_step: 51937   av_q: 0.022   av_loss: 0.0014759
# ep: 325   s.: 1   mem.len: 52083   eps: 1.0   g_step: 52083   av_q: 0.023   av_loss: 0.000999
# ep: 326   s.: 0   mem.len: 52192   eps: 1.0   g_step: 52192   av_q: 0.024   av_loss: 0.0014273
# ep: 327   s.: 1   mem.len: 52339   eps: 1.0   g_step: 52339   av_q: 0.026   av_loss: 0.0011993
# ep: 328   s.: 0   mem.len: 52448   eps: 1.0   g_step: 52448   av_q: 0.023   av_loss: 0.0012401
# ep: 329   s.: 1   mem.len: 52605   eps: 1.0   g_step: 52605   av_q: 0.024   av_loss: 0.0012221
# ep: 330   s.: 3   mem.len: 52806   eps: 1.0   g_step: 52806   av_q: 0.024   av_loss: 0.0010855
# ep: 331   s.: 3   mem.len: 53027   eps: 1.0   g_step: 53027   av_q: 0.022   av_loss: 0.0011053
# ep: 332   s.: 1   mem.len: 53173   eps: 1.0   g_step: 53173   av_q: 0.025   av_loss: 0.0013474
# ep: 333   s.: 0   mem.len: 53302   eps: 1.0   g_step: 53302   av_q: 0.025   av_loss: 0.0013643
# ep: 334   s.: 2   mem.len: 53503   eps: 1.0   g_step: 53503   av_q: 0.024   av_loss: 0.0012418
# ep: 335   s.: 0   mem.len: 53631   eps: 1.0   g_step: 53631   av_q: 0.019   av_loss: 0.0010181
# ep: 336   s.: 0   mem.len: 53734   eps: 1.0   g_step: 53734   av_q: 0.023   av_loss: 0.0017582
# ep: 337   s.: 1   mem.len: 53892   eps: 1.0   g_step: 53892   av_q: 0.025   av_loss: 0.0014778
# ep: 338   s.: 1   mem.len: 54064   eps: 1.0   g_step: 54064   av_q: 0.024   av_loss: 0.0013253
# ep: 339   s.: 1   mem.len: 54246   eps: 1.0   g_step: 54246   av_q: 0.025   av_loss: 0.0013664
# ep: 340   s.: 5   mem.len: 54561   eps: 1.0   g_step: 54561   av_q: 0.023   av_loss: 0.0010391
# ep: 341   s.: 2   mem.len: 54732   eps: 1.0   g_step: 54732   av_q: 0.021   av_loss: 0.0012454
# ep: 342   s.: 1   mem.len: 54887   eps: 1.0   g_step: 54887   av_q: 0.025   av_loss: 0.0013039
# ep: 343   s.: 0   mem.len: 54999   eps: 1.0   g_step: 54999   av_q: 0.024   av_loss: 0.0012038
# ep: 344   s.: 0   mem.len: 55120   eps: 1.0   g_step: 55120   av_q: 0.023   av_loss: 0.0012436
# ep: 345   s.: 1   mem.len: 55288   eps: 1.0   g_step: 55288   av_q: 0.023   av_loss: 0.0012959
# ep: 346   s.: 2   mem.len: 55469   eps: 1.0   g_step: 55469   av_q: 0.023   av_loss: 0.0011484
# ep: 347   s.: 0   mem.len: 55593   eps: 0.99   g_step: 55593   av_q: 0.023   av_loss: 0.0013773
# ep: 348   s.: 2   mem.len: 55798   eps: 0.99   g_step: 55798   av_q: 0.025   av_loss: 0.0013914
# ep: 349   s.: 2   mem.len: 55983   eps: 0.99   g_step: 55983   av_q: 0.023   av_loss: 0.0013189
# ep: 350   s.: 2   mem.len: 56188   eps: 0.99   g_step: 56188   av_q: 0.022   av_loss: 0.0009134
# ep: 351   s.: 0   mem.len: 56301   eps: 0.99   g_step: 56301   av_q: 0.023   av_loss: 0.0011488
# ep: 352   s.: 0   mem.len: 56419   eps: 0.99   g_step: 56419   av_q: 0.021   av_loss: 0.0011878
# ep: 353   s.: 4   mem.len: 56707   eps: 0.99   g_step: 56707   av_q: 0.026   av_loss: 0.001334
# ep: 354   s.: 0   mem.len: 56824   eps: 0.99   g_step: 56824   av_q: 0.023   av_loss: 0.0014177
# ep: 355   s.: 0   mem.len: 56945   eps: 0.99   g_step: 56945   av_q: 0.023   av_loss: 0.001202
# ep: 356   s.: 1   mem.len: 57133   eps: 0.99   g_step: 57133   av_q: 0.026   av_loss: 0.0014857
# ep: 357   s.: 3   mem.len: 57369   eps: 0.99   g_step: 57369   av_q: 0.023   av_loss: 0.0014052
# ep: 358   s.: 1   mem.len: 57548   eps: 0.99   g_step: 57548   av_q: 0.025   av_loss: 0.0014745
# ep: 359   s.: 1   mem.len: 57689   eps: 0.99   g_step: 57689   av_q: 0.027   av_loss: 0.0016124
# ep: 360   s.: 1   mem.len: 57860   eps: 0.99   g_step: 57860   av_q: 0.021   av_loss: 0.0010653
# ep: 361   s.: 2   mem.len: 58059   eps: 0.99   g_step: 58059   av_q: 0.023   av_loss: 0.0013275
# ep: 362   s.: 0   mem.len: 58162   eps: 0.99   g_step: 58162   av_q: 0.025   av_loss: 0.0015115
# ep: 363   s.: 3   mem.len: 58409   eps: 0.99   g_step: 58409   av_q: 0.023   av_loss: 0.0012376
# ep: 364   s.: 0   mem.len: 58529   eps: 0.99   g_step: 58529   av_q: 0.025   av_loss: 0.0013832
# ep: 365   s.: 0   mem.len: 58634   eps: 0.99   g_step: 58634   av_q: 0.023   av_loss: 0.0012345
# ep: 366   s.: 1   mem.len: 58787   eps: 0.99   g_step: 58787   av_q: 0.025   av_loss: 0.0012856
# ep: 367   s.: 3   mem.len: 59013   eps: 0.99   g_step: 59013   av_q: 0.026   av_loss: 0.001737
# ep: 368   s.: 0   mem.len: 59135   eps: 0.99   g_step: 59135   av_q: 0.023   av_loss: 0.0012346
# ep: 369   s.: 3   mem.len: 59404   eps: 0.99   g_step: 59404   av_q: 0.024   av_loss: 0.001308
# ep: 370   s.: 1   mem.len: 59570   eps: 0.99   g_step: 59570   av_q: 0.02   av_loss: 0.0010656
# ep: 371   s.: 1   mem.len: 59716   eps: 0.99   g_step: 59716   av_q: 0.022   av_loss: 0.0007136
# ep: 372   s.: 1   mem.len: 59873   eps: 0.99   g_step: 59873   av_q: 0.023   av_loss: 0.0012548
# ep: 373   s.: 1   mem.len: 60033   eps: 0.99   g_step: 60033   av_q: 0.021   av_loss: 0.0008131
# ep: 374   s.: 4   mem.len: 60324   eps: 0.99   g_step: 60324   av_q: 0.028   av_loss: 0.0011254
# ep: 375   s.: 0   mem.len: 60454   eps: 0.99   g_step: 60454   av_q: 0.027   av_loss: 0.0014796
# ep: 376   s.: 3   mem.len: 60717   eps: 0.99   g_step: 60717   av_q: 0.027   av_loss: 0.0011452
# ep: 377   s.: 0   mem.len: 60836   eps: 0.99   g_step: 60836   av_q: 0.027   av_loss: 0.0013498
# ep: 378   s.: 0   mem.len: 60958   eps: 0.99   g_step: 60958   av_q: 0.026   av_loss: 0.0012338
# ep: 379   s.: 2   mem.len: 61150   eps: 0.99   g_step: 61150   av_q: 0.026   av_loss: 0.0011105
# ep: 380   s.: 2   mem.len: 61340   eps: 0.99   g_step: 61340   av_q: 0.029   av_loss: 0.0014708
# ep: 381   s.: 2   mem.len: 61543   eps: 0.99   g_step: 61543   av_q: 0.029   av_loss: 0.0013044
# ep: 382   s.: 3   mem.len: 61763   eps: 0.99   g_step: 61763   av_q: 0.026   av_loss: 0.001554
# ep: 383   s.: 1   mem.len: 61932   eps: 0.99   g_step: 61932   av_q: 0.029   av_loss: 0.0012919
# ep: 384   s.: 0   mem.len: 62024   eps: 0.99   g_step: 62024   av_q: 0.025   av_loss: 0.0009624
# ep: 385   s.: 0   mem.len: 62120   eps: 0.99   g_step: 62120   av_q: 0.027   av_loss: 0.0014052
# ep: 386   s.: 0   mem.len: 62243   eps: 0.99   g_step: 62243   av_q: 0.027   av_loss: 0.0010557
# ep: 387   s.: 0   mem.len: 62361   eps: 0.99   g_step: 62361   av_q: 0.029   av_loss: 0.0011431
# ep: 388   s.: 0   mem.len: 62472   eps: 0.99   g_step: 62472   av_q: 0.023   av_loss: 0.0009373
# ep: 389   s.: 0   mem.len: 62593   eps: 0.99   g_step: 62593   av_q: 0.024   av_loss: 0.0009904
# ep: 390   s.: 2   mem.len: 62791   eps: 0.99   g_step: 62791   av_q: 0.027   av_loss: 0.001155
# ep: 391   s.: 2   mem.len: 62998   eps: 0.99   g_step: 62998   av_q: 0.032   av_loss: 0.0015024
# ep: 392   s.: 0   mem.len: 63113   eps: 0.99   g_step: 63113   av_q: 0.026   av_loss: 0.001084
# ep: 393   s.: 0   mem.len: 63244   eps: 0.99   g_step: 63244   av_q: 0.026   av_loss: 0.0012698
# ep: 394   s.: 0   mem.len: 63370   eps: 0.99   g_step: 63370   av_q: 0.024   av_loss: 0.0008694
# ep: 395   s.: 2   mem.len: 63575   eps: 0.99   g_step: 63575   av_q: 0.028   av_loss: 0.0012152
